# %%
import os
import csv
import pandas as pd
# from google.colab import files
# uploaded = files.upload()
# import drive
from google.colab import drive
drive.mount('/content/drive')

os.getcwd()
# pause = input("Press Enter to continue...")


total = 0
header = True

path="/content/drive/MyDrive/MDVData/GameReviews/all_reviews.csv"

for chunk in pd.read_csv(path, chunksize=1000):
  chunk.drop(chunk[(chunk.language != 'english')].index, inplace=True)
  chunk.to_csv('english_reviews.csv', header=header, mode='a')
  header = False
  total = total + 1
  if total > 5:
    break
print(total)

EnglishReviewsDF = pd.read_csv('english_reviews.csv')
EnglishReviewsDF.head(5)
#EnglishReviewsDF.tail(10)
#for chunk in pd.read_csv('english_reviews.csv', chunksize=1000):
#    print(chunk
#    total += sum(chunk['overall'])
#    print(total)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 6
#    Unnamed: 0  recommendationid  appid            game     author_steamid  \
# 0           4         148912575     10  Counter-Strike  76561198363716821
# 1          10         148895540     10  Counter-Strike  76561198134752176
# 2          11         148895230     10  Counter-Strike  76561197985437504
# 3          25         148865538     10  Counter-Strike  76561199015747395
# 4          28         148862089     10  Counter-Strike  76561199479067349
#
#    author_num_games_owned  author_num_reviews  author_playtime_forever  \
# 0                       0                   2                      197
# 1                      69                   1                    12107
# 2                       0                   5                    42519
# 3                      71                  34                       30
# ...

# %%
EnglishReviewsDF.head(5)['review']
# Out:
# 0                               GOAT Game !!
# 1           First crush. Always in my heart.
# 2          best version of cs ever, history.
# 3    a game everyone needs, but not to play.
# 4                               old but gold
# Name: review, dtype: object

# %%
# EnglishReviewsDF.info()
Column_Names = EnglishReviewsDF.columns
print(Column_Names)
# Out:
# Index(['Unnamed: 0', 'recommendationid', 'appid', 'game', 'author_steamid',
#        'author_num_games_owned', 'author_num_reviews',
#        'author_playtime_forever', 'author_playtime_last_two_weeks',
#        'author_playtime_at_review', 'author_last_played', 'language', 'review',
#        'timestamp_created', 'timestamp_updated', 'voted_up', 'votes_up',
#        'votes_funny', 'weighted_vote_score', 'comment_count', 'steam_purchase',
#        'received_for_free', 'written_during_early_access',
#        'hidden_in_steam_china', 'steam_china_location'],
#       dtype='object')

# %%
# Select a sample of reviews - use appid=10 ==> 'Counter-Strike' game;
SampleReviewsDF = EnglishReviewsDF[EnglishReviewsDF.iloc[:, 2] == 10]
# SampleReviewsDF = EnglishReviewsDF
# Next line is faulty as it interprets the multiple column names as a tuple
# SampleReviewsDF.head(3)['appid', 'game']
# Instead, to correct the fault, Use .loc to access multiple columns
SampleReviewsDF.loc[SampleReviewsDF.head(3).index, ['appid', 'game']]
# Out:
#    appid            game
# 0     10  Counter-Strike
# 1     10  Counter-Strike
# 2     10  Counter-Strike

# %%
SampleReviewsDF.loc[SampleReviewsDF.head(100).index, ['appid', 'game']]
# Out:
#     appid            game
# 0      10  Counter-Strike
# 1      10  Counter-Strike
# 2      10  Counter-Strike
# 3      10  Counter-Strike
# 4      10  Counter-Strike
# ..    ...             ...
# 95     10  Counter-Strike
# 96     10  Counter-Strike
# 97     10  Counter-Strike
# 98     10  Counter-Strike
# 99     10  Counter-Strike
#
# [100 rows x 2 columns]

# %%
# SampleReviewsDF.to_csv('Sample_Reviews.csv', header=header, mode='a')

path="/content/drive/MyDrive/MDVData/GameReviews/SAMPLES/Sample_All_reviewsEN.csv"
SampleReviewsDF.to_csv(path, header=header, mode='a')

# %%
pathGames="/content/drive/MyDrive/MDVData/GameReviews/games.csv"

header = True
total = 0

for chunk in pd.read_csv(pathGames, chunksize=1000):
  chunk.to_csv('games.csv', header=header, mode='a')
  header = False
  total = total + 1
  if total > 5:
    break
print(total)
GamesDF = pd.read_csv('games.csv')
GamesDF.head(5)
# GamesDF.columns
# Out:
# 6
#    Unnamed: 0                  AppID          Name Release date  \
# 0       20200       Galactic Bowling  Oct 21, 2008    0 - 20000
# 1      655370           Train Bandit  Oct 12, 2017    0 - 20000
# 2     1732930           Jolt Project  Nov 17, 2021    0 - 20000
# 3     1355720               Henosis™  Jul 23, 2020    0 - 20000
# 4     1139950  Two Weeks in Painland   Feb 3, 2020    0 - 20000
#
#    Estimated owners  Peak CCU  Required age  Price  DiscountDLC count  \
# 0                 0         0         19.99      0                  0
# 1                 0         0          0.99      0                  0
# 2                 0         0          4.99      0                  0
# 3                 0         0          5.99      0                  0
# 4                 0         0          0.00      0                  0
#
#                                       About the game  ...  \
# 0  Galactic Bowling is an exaggerated and stylize...  ...
# ...

# %%
SampleGamesDF = GamesDF
# SampleGamesDF.head(3)
SubSampleGamesDF = SampleGamesDF
# Check column located at Index position 0 {'Unnamed: 0;'AppID': 1}
# SubSampleGamesDF.iloc[:, 2].head(3)

# Select a sample of reviews - use appid=10 ==> 'Counter-Strike' game;
# SubSampleGamesDF = SampleGamesDF[SampleGamesDF.iloc[:, 1] == 'Galatic Bowling']

# This next line works ok, i.e. it finds a matching record
# SampleGamesDF = GamesDF[GamesDF.iloc[:, 0] == 20200]
# SampleReviewsDF = EnglishReviewsDF
# Use .loc to access multiple columns

# SubSampleGamesDF.loc[SubSampleGamesDF.head(3).index, ['Unnamed: 0', 'AppID', 'Name']]
# SubSampleGamesDF.loc[SubSampleGamesDF.head(3).index, ['Unnamed: 0']]
# SubSampleGamesDF.loc[SubSampleGamesDF.head(3).index, ['AppID']]
# SubSampleGamesDF.loc[SubSampleGamesDF.head(3).index, ['Name']]

path="/content/drive/MyDrive/MDVData/GameReviews/SAMPLES/Sample_Games.csv"
SubSampleGamesDF.to_csv(path, header=header, mode='a')

# %%
Column_Names = GamesDF.columns
print(Column_Names)
# Out:
# Index(['20200', 'Galactic Bowling', 'Oct 21, 2008', '0 - 20000', '0', '0.1',
#        '19.99', '0.2', '0.3',
# ...

# %%
GamesDF.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 40 columns):
# ...

# %%
pathWeightedGames="/content/drive/MyDrive/MDVData/GameReviews/weighted_score_above_08.csv"

header = True
total = 0

for chunk in pd.read_csv(pathWeightedGames, chunksize=1000):
  # chunk.drop(chunk[(chunk.language != 'english')].index, inplace=True)
  # Access the value in the each row (index 10), the language value
  # LangColValue = chunk.iloc[:, 10]
  # print(LangColValue)
  chunk.drop(chunk[(chunk.iloc[:, 11] != 'english')].index, inplace=True)
  chunk.to_csv('weighted_score_above_08.csv', header=header, mode='a')
  header = False
  total = total + 1
  if total > 5:
    break
print(total)
WGamesDF = pd.read_csv('weighted_score_above_08.csv')
# LangColValue = WGamesDF.iloc[:, 11]
# print(LangColValue)
ENWGamesDF = WGamesDF[WGamesDF.iloc[:, 11] == 'english']
ENWGamesDF.head(3)
# ENWGamesDF.iloc[:, 11].head(3)
# ENWGamesDF.columns
# Out:
# 6
#        0  147449116  10  Counter-Strike  76561199183984450  51  12    2548  \
# 4    5.0  147263134  10  Counter-Strike  76561199013220131  41  10    2510
# 8    9.0  146253831  10  Counter-Strike  76561198847956367   0   1  404175
# 16  17.0  145002893  10  Counter-Strike  76561198995972388  50  50      81
#
#      0.1    2480  ...  1   99   2  0.889438092708588 0.2 1.1 0.3 0.4 1.2  \
# 4      0     221  ...  1  300  13  0.863652169704437   0   1   0   0   1
# 8   1486  396410  ...  1  102   1  0.865921974182129   0   1   0   0   1
# 16     0      81  ...  1  208  31  0.935512900352478   0   1   0   0   1
#
#    Unnamed: 24
# 4          NaN
# 8          NaN
# 16         NaN
#
# [3 rows x 25 columns]

# %%
import os
import csv
import pandas as pd
# from google.colab import files
# uploaded = files.upload()
# import drive
from google.colab import drive
drive.mount('/content/drive')

# load Recommendations Users table

total = 0
header = True

Userspath="/content/drive/MyDrive/MDVData/GamesRecommendations/users.csv"
# Recmdspath="/content/drive/MyDrive/MDVData/GamesRecommendations/recommendations.csv"
# Gamespath="/content/drive/MyDrive/MDVData/GamesRecommendations/games.csv"

for chunk in pd.read_csv(Userspath, chunksize=1000):
  chunk.to_csv('users.csv', header=header, mode='a')
  header = False
  total = total + 1
  if total > 5:
    break
print(total)

UsersDF = pd.read_csv('users.csv')
SampleRecsUsersDF = UsersDF.head(5)
path="/content/drive/MyDrive/MDVData/GameReviews/SAMPLES/Sample_Rec_Users.csv"
SampleRecsUsersDF.to_csv(path, header=header, mode='a')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 6

# %%
total = 0
header = True

# Userspath="/content/drive/MyDrive/MDVData/GamesRecommendations/users.csv"
Recmdspath="/content/drive/MyDrive/MDVData/GamesRecommendations/recommendations.csv"
# Gamespath="/content/drive/MyDrive/MDVData/GamesRecommendations/games.csv"

for chunk in pd.read_csv(Recmdspath, chunksize=1000):
  chunk.to_csv('recommendations.csv', header=header, mode='a')
  header = False
  total = total + 1
  if total > 5:
    break
print(total)

RecmdsDF = pd.read_csv('recommendations.csv')
SampleRecsRecmdsDF = RecmdsDF.head(5)
path="/content/drive/MyDrive/MDVData/GameReviews/SAMPLES/Sample_Rec_Recommendations.csv"
SampleRecsRecmdsDF.to_csv(path, header=header, mode='a')
# Out:
# 6

# %%
total = 0
header = True

# Userspath="/content/drive/MyDrive/MDVData/GamesRecommendations/users.csv"
# Recmdspath="/content/drive/MyDrive/MDVData/GamesRecommendations/recommendations.csv"
RecGamespath="/content/drive/MyDrive/MDVData/GamesRecommendations/games.csv"

for chunk in pd.read_csv(RecGamespath, chunksize=1000):
  chunk.to_csv('RecGames.csv', header=header, mode='a')
  header = False
  total = total + 1
  if total > 1:
    break
print(total)

RecGamesDF = pd.read_csv('RecGames.csv')
SampleRecsGamesDF = RecGamesDF.head(5)
path="/content/drive/MyDrive/MDVData/GameReviews/SAMPLES/Sample_Rec_Games.csv"
SampleRecsGamesDF.to_csv(path, header=header, mode='a')
# Out:
# 2
